# %%
import pandas
import datetime

# %%
colNames = [ "dateStr", "timeStr", "MLAT", "MLT",\
            "vel", "azims", "stIds", "poesMLAT1", "poesMLAT2" ]
esDF = pandas.read_csv( "../data/east-saps-north-2011-2014.txt",\
                       delim_whitespace=True, header=None,\
                      names=colNames)
esDF.head()
# Out:
# /usr/local/lib/python2.7/dist-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     dateStr  timeStr  MLAT     MLT       vel    azims    stIds poesMLAT1  \
# 0  20110101      700  56.5  1.8816  646.2470  90.6797  33.0000   67.1833
# 1  20110101      800  54.5  2.7046  714.3559  90.3934  33.0000   66.3544
# 2  20110101      800  54.5  2.8194  723.4858  90.3635  33.0000   66.3544
# 3  20110101      800  55.5  2.6863  673.4401  91.1488  33.0000   66.3544
# 4  20110101      800  55.5  2.8039  680.2266  91.0594  33.0000   66.3544
#
#    poesMLAT2
# 0    67.0988
# 1    66.5381
# 2    66.5381
# 3    66.5381
# 4    66.5381

# %%
# get counts of datetime measurements
esCntDate = esDF[ esDF["MLT"] > 12. ].groupby( ["dateStr" ] ).size().reset_index()
esCntDate.columns = [ "dateStr", "cnt" ]
esCntDate = esCntDate.sort( ["cnt"], ascending=False ).reset_index(drop=True)
esCntDate.head(20)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   after removing the cwd from sys.path.
#      dateStr  cnt
# 0   20111204  315
# 1   20121213  263
# 2   20121217  245
# 3   20120108  231
# 4   20130425  229
# 5   20130227  223
# 6   20120127  207
# 7   20131117  181
# 8   20120205  177
# 9   20111125  177
# 10  20120111  170
# 11  20120221  165
# 12  20120206  159
# 13  20131108  159
# 14  20121102  155
# 15  20120121  155
# 16  20130221  153
# 17  20131016  153
# 18  20120124  153
# 19  20111130  151

# %%
print esDF[ (esDF["dateStr"] == 20130425)  ].groupby( ["timeStr" ] ).size()
# Out:
# timeStr
# 130      1
# 230      3
# 330      1
# 430     55
# 500     11
# 530     20
# 600     51
# 700      4
# 800      6
# 830     13
# 900      8
# 930     17
# 1000     3
# 1030    21
# 1130    11
# 1300     3
# 2300     1
# dtype: int64

# %%
print esDF[ (esDF["dateStr"] == 20130425) &\
          (esDF["timeStr"] == 430)]
# Out:
#         dateStr  timeStr  MLAT      MLT       vel     azims     stIds  \
# 62309  20130425      430  58.5  22.0030  260.9282  104.4118   33.0000
# 62310  20130425      430  59.5  21.9559  289.2906   98.0705   33.0000
# 62311  20130425      430  59.5  22.2182  244.4763  102.0620   33.0000
# 62312  20130425      430  59.5  22.0870  267.5842   99.9252   33.0000
# 62313  20130425      430  60.5  22.0315  290.7335   94.7497   33.0000
# 62314  20130425      430  60.5  21.8959  306.8198   93.7790   33.0000
# 62315  20130425      430  59.5  22.3493  220.3131  104.5784   33.0000
# 62316  20130425      430  60.5  22.3027  252.7263   97.0193   33.0000
# 62317  20130425      430  60.5  22.1671  272.6160   95.8196   33.0000
# 62318  20130425      430  61.5  21.9822  279.8898   92.0301   33.0000
# 62319  20130425      430  60.5  22.4382  231.3540   98.3914   33.0000
# 62320  20130425      430  61.5  22.2613  257.3875   93.0317   33.0000
# ...
